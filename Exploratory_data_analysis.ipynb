# %% [markdown]
# **Exploratory Data Analytics**

# %%
#importing libraries for EDA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\LENOVO\Desktop\ANN CLASS\DataCosupplyChainDataset.csv',header=0,encoding='unicode_escape')
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %% [markdown]
# Finding the missing values inside the features

# %%
def features_with_missing_values(df):
    for i in df.columns:
        if df[i].isna().sum()>0:
            print('The Feature ',i,' has '+ str(df[i].isna().sum()) + ' missing values')
            
features_with_missing_values(df)
# Out:
# The Feature  Customer Lname  has 8 missing values
# The Feature  Customer Zipcode  has 3 missing values
# The Feature  Order Zipcode  has 155679 missing values
# The Feature  Product Description  has 180519 missing values

# %% [markdown]
# Now we will check the corelation between our dataset using seaborn library

# %%
corrmap=df.corr()
top=corrmap.index
graph=sns.heatmap(df[top].corr())

# %%
#The graph coming here is small and color is not very helping so we will change that
corrmap=df.corr()
plt.figure(figsize=(25,25))
top=corrmap.index
graph=sns.heatmap(df[top].corr(),cmap="Blues")

# %% [markdown]
# As the data is confusing we will try to split our data according to the domain

# %% [markdown]
# We will split them in profit and shipping

# %%
shipping = ['Type','Days for shipping (real)','Days for shipment (scheduled)','Late_delivery_risk','Benefit per order',
                        'Sales per customer','Latitude','Longitude','Shipping Mode','Order Status','Order Region',
                        'Order Country','Order City','Market','Delivery Status']
shipment = df[shipping]
shipment.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Late_delivery_risk  Benefit per order  Sales per customer   Latitude  \
# 0                   0          91.250000          314.640015  18.251453
# 1                   1        -249.089996          311.359985  18.279451
# 2                   0        -247.779999          309.720001  37.292233
# 3                   0          22.860001          304.809998  34.125946
# 4                   0         134.210007          298.250000  18.253769
#
#     Longitude   Shipping Mode     Order Status    Order Region Order Country  \
# ...

# %%
shipment.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Late_delivery_risk  Benefit per order  Sales per customer  \
# count       180519.000000      180519.000000       180519.000000
# mean             0.548291          21.974989          183.107609
# std              0.497664         104.433526          120.043670
# min              0.000000       -4274.979980            7.490000
# 25%              0.000000           7.000000          104.379997
# ...

# %%
shipment.corr()
# Out:
#                                Days for shipping (real)  \
# Days for shipping (real)                       1.000000
# Days for shipment (scheduled)                  0.515880
# Late_delivery_risk                             0.401415
# Benefit per order                             -0.005101
# Sales per customer                             0.001757
# Latitude                                      -0.004073
# Longitude                                      0.003911
#
#                                Days for shipment (scheduled)  \
# Days for shipping (real)                            0.515880
# Days for shipment (scheduled)                       1.000000
# Late_delivery_risk                                 -0.369352
# Benefit per order                                  -0.000185
# Sales per customer                                  0.006445
# Latitude                                           -0.005300
# Longitude                                           0.003675
#
# ...

# %%
profit=['Benefit per order','Sales per customer','Order Item Discount','Order Item Discount Rate',
                  'Order Item Product Price','Order Item Profit Ratio']
finance = df[profit]
finance.head()
# Out:
#    Benefit per order  Sales per customer  Order Item Discount  \
# 0          91.250000          314.640015            13.110000
# 1        -249.089996          311.359985            16.389999
# 2        -247.779999          309.720001            18.030001
# 3          22.860001          304.809998            22.940001
# 4         134.210007          298.250000            29.500000
#
#    Order Item Discount Rate  Order Item Product Price  Order Item Profit Ratio
# 0                      0.04                    327.75                     0.29
# 1                      0.05                    327.75                    -0.80
# 2                      0.06                    327.75                    -0.80
# 3                      0.07                    327.75                     0.08
# 4                      0.09                    327.75                     0.45

# %%
finance.describe()
# Out:
#        Benefit per order  Sales per customer  Order Item Discount  \
# count      180519.000000       180519.000000        180519.000000
# mean           21.974989          183.107609            20.664741
# std           104.433526          120.043670            21.800901
# min         -4274.979980            7.490000             0.000000
# 25%             7.000000          104.379997             5.400000
# 50%            31.520000          163.990005            14.000000
# 75%            64.800003          247.399994            29.990000
# max           911.799988         1939.989990           500.000000
#
#        Order Item Discount Rate  Order Item Product Price  \
# count             180519.000000             180519.000000
# mean                   0.101668                141.232550
# std                    0.070415                139.732492
# min                    0.000000                  9.990000
# 25%                    0.040000                 50.000000
# ...

# %%
finance.corr()
# Out:
#                           Benefit per order  Sales per customer  \
# Benefit per order                  1.000000            0.133484
# Sales per customer                 0.133484            1.000000
# Order Item Discount                0.064756            0.498734
# Order Item Discount Rate          -0.018644           -0.119469
# Order Item Product Price           0.103459            0.781781
# Order Item Profit Ratio            0.823689           -0.001439
#
#                           Order Item Discount  Order Item Discount Rate  \
# Benefit per order                    0.064756                 -0.018644
# Sales per customer                   0.498734                 -0.119469
# Order Item Discount                  1.000000                  0.659955
# Order Item Discount Rate             0.659955                  1.000000
# Order Item Product Price             0.488101                  0.000345
# Order Item Profit Ratio             -0.002788                 -0.002691
#
# ...
